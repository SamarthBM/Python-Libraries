# %% [markdown]
# """
# * @Author: Samarth BM.
# * @Date: 2021-09-29 14:14
# * @Last Modified by: Samarth BM
# * @Last Modified time: 2021-09-29 14:14
# * @Title: To draw bar plot of sex against survived and count the sex from the titanic data set.
#  """

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set_style('whitegrid') # darkgrid, white, dark, ticks.

# df = sns.load_dataset('titanic')
df = pd.read_csv('titanic.csv')

sns.barplot(x = "sex", y = "survived", data = df)
plt.show()

# %%
sns.countplot(y ='sex', data=df)

plt.show()

# %%
sns.barplot(x='who', y='fare',data=df)
plt.show()
