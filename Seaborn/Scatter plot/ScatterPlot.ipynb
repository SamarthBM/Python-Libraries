# %% [markdown]
# """
# * @Author: Samarth BM.
# * @Date: 2021-09-29 15:45
# * @Last Modified by: Samarth BM
# * @Last Modified time: 2021-09-29 15:45
# * @Title: To draw scatter plot of sex against day and totl bill from the tips data set.
#  """

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from LogHandler import logger

try:

    sns.set_style('dark') 

    df = pd.read_csv('tips.csv')
    plt.figure(figsize=(10,6))

    sns.scatterplot(x = "day", y = "total_bill", data = df)
    plt.show()

except Exception as e:
    logger.error(e)
