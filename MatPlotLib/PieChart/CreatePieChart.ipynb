# %% [markdown]
# """
# * @Author: Samarth BM.
# * @Date: 2021-09-28 20:48
# * @Last Modified by: Samarth BM
# * @Last Modified time: 2021-09-28 20:48
# * @Title: To create a pie chart of the popularity of programming Languages.
# """

# %%
import matplotlib.pyplot as plt
from LogHandler import logger

try:
    
    languages = 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'
    popuratity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
        
    plt.pie(popuratity, labels=languages, startangle=90)

    plt.show()
    
except Exception as e:
    logger.error(e)
