# %% [markdown]
# """
# * @Author: Samarth BM.
# * @Date: 2021-09-29 15:34
# * @Last Modified by: Samarth BM
# * @Last Modified time: 2021-09-29 15:34
# * @Title: To draw point plot of sex against survived and count the sex from the titanic data set.
#  """

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from LogHandler import logger

try:
    
    sns.set_style('whitegrid') # darkgrid, white, dark, ticks.

    df = pd.read_csv('titanic.csv')

    sns.pointplot(x = "sex", y = "survived", markers='^' , data = df)
    plt.show()

except Exception as e:
    logger.error(e)
