# %% [markdown]
# """
# * @Author: Samarth BM.
# * @Date: 2021-09-27 23:15
# * @Last Modified by: Samarth BM
# * @Last Modified time: 2021-09-27 23:15
# * @Title: To plot two or more lines with different styles.
#  """

# %%
from matplotlib import pyplot as plt
from LogHandler import logger

try:
    
    x = (1,2,3,4,5,6)
    y = [num**2 for num in x]
    print(x)
    print(y)

    plt.plot(x, color = "green", linewidth = 3 ,label = "Numbers", linestyle = "dotted")
    plt.plot(y, color = "red", linewidth = 3 ,label = "Square of numbers",  linestyle = "dashdot")

    plt.xlabel("X-axis")
    plt.ylabel("y-axis")
    plt.title("Two lines on same plot with legend")

    plt.legend()
    plt.show()

except Exception as e:
    logger.error(e)
# Out:
# (1, 2, 3, 4, 5, 6)
# [1, 4, 9, 16, 25, 36]
